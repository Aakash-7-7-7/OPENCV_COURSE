# %%
import cv2 as cv 

image=cv.imread("tank.png")

cv.imshow("image", image)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
crop=image[0:1980,600:1980]

cv.imshow("crop",crop)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
import cv2 as cv
import numpy as np 
from matplotlib import pyplot as plt 

# In RGB (for Matplotlib), Blue is [0, 0, 255]
# Since we will convert the whole image to RGB later, define it in RGB format
BLUE = [0, 0, 255]

# 1. Load the image
img_bgr = cv.imread("tank.png")

# 2. Convert BGR to RGB so Matplotlib displays correct colors
img1 = cv.cvtColor(img_bgr, cv.COLOR_BGR2RGB)

# 3. Increase border size to 100 so it is clearly visible on a large image
border_size = 100
replicate = cv.copyMakeBorder(img1, border_size, border_size, border_size, border_size, cv.BORDER_REPLICATE)
reflect = cv.copyMakeBorder(img1, border_size, border_size, border_size, border_size, cv.BORDER_REFLECT)
reflect101 = cv.copyMakeBorder(img1, border_size, border_size, border_size, border_size, cv.BORDER_REFLECT101)
wrap = cv.copyMakeBorder(img1, border_size, border_size, border_size, border_size, cv.BORDER_WRAP)
constant = cv.copyMakeBorder(img1, border_size, border_size, border_size, border_size, cv.BORDER_CONSTANT, value=BLUE)

# 4. Plot using Matplotlib (removed the 'gray' argument since it's a color image)
plt.subplot(231), plt.imshow(img1), plt.title('ORIGINAL')
plt.subplot(232), plt.imshow(replicate), plt.title('REPLICATE')
plt.subplot(233), plt.imshow(reflect), plt.title('REFLECT')
plt.subplot(234), plt.imshow(reflect101), plt.title('REFLECT_101')
plt.subplot(235), plt.imshow(wrap), plt.title('WRAP')
plt.subplot(236), plt.imshow(constant), plt.title('CONSTANT')

plt.tight_layout()
plt.show()
